# %%
import pandas as pd

linkData='https://github.com/Kent253/computuer-analysis/raw/main/GenderProject/allData5.csv'

FullData=pd.read_csv(linkData)

# %%
FullData.columns
# Out:
# Index(['GIIRank', 'HDIRank', 'Country', 'GIIValue',
#        'Current Health Expenditure (CHE) as % Gross Domestic Product (GDP) in 2019',
#        'Expenditure on education(% of government spending)', 'Year', 'True'],
#       dtype='object')

# %%
FullData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133 entries, 0 to 132
# Data columns (total 8 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   GIIRank                                                                     118 non-null    float64
#  1   HDIRank                                                                     118 non-null    float64
#  2   Country                                                                     133 non-null    object
#  3   GIIValue                                                                    118 non-null    float64
#  4   Current Health Expenditure (CHE) as % Gross Domestic Product (GDP) in 2019  118 non-null    float64
#  5   Expenditure on education(% of government spending)                          133 non-null    float64
# ...

# %%
FullData.describe(include='all')
# Out:
#            GIIRank     HDIRank      Country    GIIValue  \
# count   118.000000  118.000000          133  118.000000
# unique         NaN         NaN          133         NaN
# top            NaN         NaN  Switzerland         NaN
# freq           NaN         NaN            1         NaN
# mean     79.186441   89.601695          NaN    0.335398
# std      48.415571   57.581624          NaN    0.195285
# min       1.000000    1.000000          NaN    0.025000
# 25%      35.250000   38.250000          NaN    0.133000
# 50%      80.500000   86.000000          NaN    0.359500
# 75%     123.750000  138.000000          NaN    0.500000
# max     160.000000  189.000000          NaN    0.710000
#
#         Current Health Expenditure (CHE) as % Gross Domestic Product (GDP) in 2019  \
# count                                          118.000000
# unique                                                NaN
# top                                                   NaN
# ...

# %%
FullData_LONG=FullData.melt(id_vars=['Country','Year'])
FullData_LONG
# Out:
#                    Country    Year variable       value
# 0              Switzerland  2016.0  GIIRank         1.0
# 1                   Norway  2015.0  GIIRank         2.0
# 2                  Finland  2015.0  GIIRank         3.0
# 3              Netherlands  2015.0  GIIRank         4.0
# 4                  Denmark  2014.0  GIIRank         4.0
# ..                     ...     ...      ...         ...
# 793             Seychelles  2016.0     True  right_only
# 794               Dominica  2015.0     True  right_only
# 795  Saint Kitts and Nevis  2015.0     True  right_only
# 796            Timor-Leste  2014.0     True  right_only
# 797            South Sudan  2017.0     True  right_only
#
# [798 rows x 4 columns]

# %%
FullData_LONG.to_csv('FullData_LONG.csv',index=False)

# %%
# !pip install plotnine   

import plotnine as p9


base=p9.ggplot(data=FullData_LONG)
base + p9.geom_boxplot(p9.aes(x='variable',y='value')) + p9.coord_flip()
# Out:
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     392                         if cls is not object \
#     393                                 and callable(cls.__dict__.get('__repr__')):
# --> 394                             return _repr_pprint(obj, self, cycle)
#     395
#     396             return _default_pprint(obj, self, cycle)
#
# ~\anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
# ...
